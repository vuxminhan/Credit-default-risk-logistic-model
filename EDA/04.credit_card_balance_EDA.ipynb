# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

sns.set_theme()
pd.options.display.float_format = '{:,.2f}'.format

# %%
CCBL = pd.read_csv(r"C:\Users\swift\Downloads\input\inputs\credit_card_balance.csv")

# %%
CCBL
# Out:
#          SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  AMT_CREDIT_LIMIT_ACTUAL  \
# 0           2582071              -1    63,975.56                    45000
# 1           2582071             -82    16,809.21                    67500
# 2           2582071             -84    27,577.89                    67500
# 3           2582071              -7    65,159.24                    45000
# 4           2582071             -59    70,475.85                    67500
# ...             ...             ...          ...                      ...
# 3227960     1551072              -1         0.00                   202500
# 3227961     2339982              -1         0.00                    45000
# 3227962     2720102              -1         0.00                   225000
# 3227963     1897864              -2         0.00                   270000
# 3227964     2481982              -1         0.00                   270000
#
#          AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# 0                        2,250.00              2,250.00
# 1                            0.00                  0.00
# 2                            0.00                  0.00
# 3                            0.00                  0.00
# 4                       24,750.00             24,750.00
# ...                           ...                   ...
# 3227960                       NaN                  0.00
# 3227961                      0.00                  0.00
# 3227962                       NaN                  0.00
# 3227963                       NaN                  0.00
# 3227964                       NaN                  0.00
#
#          AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# 0                              0.00                      0.00
# 1                              0.00                      0.00
# 2                              0.00                      0.00
# 3                              0.00                      0.00
# 4                              0.00                      0.00
# ...                             ...                       ...
# 3227960                         NaN                       NaN
# 3227961                        0.00                      0.00
# 3227962                         NaN                       NaN
# 3227963                         NaN                       NaN
# 3227964                         NaN                       NaN
#
#          AMT_INST_MIN_REGULARITY  AMT_PAYMENT_CURRENT  ...  \
# 0                       2,250.00             2,250.00  ...
# 1                       3,375.00             9,000.00  ...
# 2                       3,375.00             4,500.00  ...
# 3                       2,250.00             2,250.00  ...
# 4                       3,375.00             4,500.00  ...
# ...                          ...                  ...  ...
# 3227960                     0.00                  NaN  ...
# 3227961                     0.00                  NaN  ...
# 3227962                     0.00                  NaN  ...
# 3227963                     0.00                  NaN  ...
# 3227964                     0.00                  NaN  ...
#
#          AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 0                   64,875.56                      1.00                     1
# 1                   16,809.21                      0.00                     0
# 2                   27,577.89                      0.00                     0
# 3                   65,609.24                      0.00                     0
# 4                   70,475.85                      4.00                     4
# ...                       ...                       ...                   ...
# 3227960                  0.00                       NaN                     0
# 3227961                  0.00                      0.00                     0
# 3227962                  0.00                       NaN                     0
# 3227963                  0.00                       NaN                     0
# 3227964                  0.00                       NaN                     0
#
#          CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 0                              0.00                      0.00
# 1                              0.00                      0.00
# 2                              0.00                      0.00
# 3                              0.00                      0.00
# 4                              0.00                      0.00
# ...                             ...                       ...
# 3227960                         NaN                       NaN
# 3227961                        0.00                      0.00
# 3227962                         NaN                       NaN
# 3227963                         NaN                       NaN
# 3227964                         NaN                       NaN
#
#          CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                            69.00                Active       0           0
# 1                            18.00                Active       0           0
# 2                            16.00                Active       0           0
# 3                            63.00                Active       0           0
# 4                            41.00                Active       0           0
# ...                            ...                   ...     ...         ...
# 3227960                       0.00                Active       0           0
# 3227961                       0.00                Active       0           0
# 3227962                       0.00                Active       0           0
# 3227963                       0.00                Active       0           0
# 3227964                       0.00                Active       0           0
#
#         SK_ID_CURR
# 0            87788
# 1            87788
# 2            87788
# 3            87788
# 4            87788
# ...            ...
# 3227960     259579
# 3227961     220697
# 3227962      93573
# 3227963      11072
# 3227964     258032
#
# [3227965 rows x 23 columns]

# %%
CCBL.head()
# Out:
#    SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  AMT_CREDIT_LIMIT_ACTUAL  \
# 0     2582071              -1    63,975.56                    45000
# 1     2582071             -82    16,809.21                    67500
# 2     2582071             -84    27,577.89                    67500
# 3     2582071              -7    65,159.24                    45000
# 4     2582071             -59    70,475.85                    67500
#
#    AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 0                  2,250.00              2,250.00                        0.00
# 1                      0.00                  0.00                        0.00
# 2                      0.00                  0.00                        0.00
# 3                      0.00                  0.00                        0.00
# 4                 24,750.00             24,750.00                        0.00
#
#    AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY  AMT_PAYMENT_CURRENT  \
# 0                      0.00                 2,250.00             2,250.00
# 1                      0.00                 3,375.00             9,000.00
# 2                      0.00                 3,375.00             4,500.00
# 3                      0.00                 2,250.00             2,250.00
# 4                      0.00                 3,375.00             4,500.00
#
#    ...  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 0  ...             64,875.56                      1.00                     1
# 1  ...             16,809.21                      0.00                     0
# 2  ...             27,577.89                      0.00                     0
# 3  ...             65,609.24                      0.00                     0
# 4  ...             70,475.85                      4.00                     4
#
#    CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 0                        0.00                      0.00
# 1                        0.00                      0.00
# 2                        0.00                      0.00
# 3                        0.00                      0.00
# 4                        0.00                      0.00
#
#    CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                      69.00                Active       0           0
# 1                      18.00                Active       0           0
# 2                      16.00                Active       0           0
# 3                      63.00                Active       0           0
# 4                      41.00                Active       0           0
#
#   SK_ID_CURR
# 0      87788
# 1      87788
# 2      87788
# 3      87788
# 4      87788
#
# [5 rows x 23 columns]

# %%
CCBL.sort_values(by= "SK_ID_CURR")
# Out:
#          SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  AMT_CREDIT_LIMIT_ACTUAL  \
# 2890867     1745718              -3    36,569.43                   180000
# 2890860     1745718              -4         0.00                   180000
# 2890861     1745718              -5         0.00                   180000
# 2890862     1745718              -8     4,500.00                   180000
# 2890866     1745718              -7         0.00                   180000
# ...             ...             ...          ...                      ...
# 928489      1147091             -20         0.00                        0
# 928488      1147091             -39         0.00                        0
# 928487      1147091             -85         0.00                   112500
# 928459      1147091              -1         0.00                        0
# 928477      1147091             -16         0.00                        0
#
#          AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# 2890867                      0.00             56,187.00
# 2890860                      0.00                  0.00
# 2890861                      0.00                  0.00
# 2890862                      0.00              4,500.00
# 2890866                      0.00              2,578.50
# ...                           ...                   ...
# 928489                       0.00                  0.00
# 928488                       0.00                  0.00
# 928487                       0.00                  0.00
# 928459                       0.00                  0.00
# 928477                       0.00                  0.00
#
#          AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# 2890867                        0.00                 56,187.00
# 2890860                        0.00                      0.00
# 2890861                        0.00                      0.00
# 2890862                        0.00                  4,500.00
# 2890866                        0.00                  2,578.50
# ...                             ...                       ...
# 928489                         0.00                      0.00
# 928488                         0.00                      0.00
# 928487                         0.00                      0.00
# 928459                         0.00                      0.00
# 928477                         0.00                      0.00
#
#          AMT_INST_MIN_REGULARITY  AMT_PAYMENT_CURRENT  ...  \
# 2890867                     0.00            16,650.00  ...
# 2890860                     0.00               488.07  ...
# 2890861                     0.00               488.07  ...
# 2890862                     0.00                  NaN  ...
# 2890866                     0.00             7,771.50  ...
# ...                          ...                  ...  ...
# 928489                      0.00               596.43  ...
# 928488                      0.00               596.43  ...
# 928487                      0.00               596.43  ...
# 928459                      0.00               596.43  ...
# 928477                      0.00               596.43  ...
#
#          AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 2890867             36,569.43                      0.00                     6
# 2890860                  0.00                      0.00                     0
# 2890861                  0.00                      0.00                     0
# 2890862              4,500.00                      0.00                     1
# 2890866                  0.00                      0.00                     1
# ...                       ...                       ...                   ...
# 928489                   0.00                      0.00                     0
# 928488                   0.00                      0.00                     0
# 928487                   0.00                      0.00                     0
# 928459                   0.00                      0.00                     0
# 928477                   0.00                      0.00                     0
#
#          CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 2890867                        0.00                      6.00
# 2890860                        0.00                      0.00
# 2890861                        0.00                      0.00
# 2890862                        0.00                      1.00
# 2890866                        0.00                      1.00
# ...                             ...                       ...
# 928489                         0.00                      0.00
# 928488                         0.00                      0.00
# 928487                         0.00                      0.00
# 928459                         0.00                      0.00
# 928477                         0.00                      0.00
#
#          CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 2890867                       0.00                Active       0           0
# 2890860                       0.00                Active       0           0
# 2890861                       0.00                Active       0           0
# 2890862                       0.00                Active       0           0
# 2890866                       0.00                Active       0           0
# ...                            ...                   ...     ...         ...
# 928489                        9.00                Active       0           0
# 928488                        9.00                Active       0           0
# 928487                        9.00                Active       0           0
# 928459                        9.00                Active       0           0
# 928477                        9.00                Active       0           0
#
#         SK_ID_CURR
# 2890867          0
# 2890860          0
# 2890861          0
# 2890862          0
# 2890866          0
# ...            ...
# 928489      307509
# 928488      307509
# 928487      307509
# 928459      307509
# 928477      307509
#
# [3227965 rows x 23 columns]

# %%
CCBL.isnull().sum()
# Out:
# SK_ID_PREV                         0
# MONTHS_BALANCE                     0
# AMT_BALANCE                        0
# AMT_CREDIT_LIMIT_ACTUAL            0
# AMT_DRAWINGS_ATM_CURRENT      605754
# AMT_DRAWINGS_CURRENT               0
# AMT_DRAWINGS_OTHER_CURRENT    605754
# AMT_DRAWINGS_POS_CURRENT      605754
# AMT_INST_MIN_REGULARITY       264384
# AMT_PAYMENT_CURRENT           620093
# AMT_PAYMENT_TOTAL_CURRENT          0
# AMT_RECEIVABLE_PRINCIPAL           0
# AMT_RECIVABLE                      0
# AMT_TOTAL_RECEIVABLE               0
# CNT_DRAWINGS_ATM_CURRENT      605754
# CNT_DRAWINGS_CURRENT               0
# CNT_DRAWINGS_OTHER_CURRENT    605754
# CNT_DRAWINGS_POS_CURRENT      605754
# CNT_INSTALMENT_MATURE_CUM     264384
# NAME_CONTRACT_STATUS               0
# SK_DPD                             0
# SK_DPD_DEF                         0
# SK_ID_CURR                         0
# dtype: int64

# %%
CCBL.duplicated().sum()
# Out:
# 0

# %%
CCBL.isnull().sum()
# Out:
# SK_ID_PREV                         0
# MONTHS_BALANCE                     0
# AMT_BALANCE                        0
# AMT_CREDIT_LIMIT_ACTUAL            0
# AMT_DRAWINGS_ATM_CURRENT      605754
# AMT_DRAWINGS_CURRENT               0
# AMT_DRAWINGS_OTHER_CURRENT    605754
# AMT_DRAWINGS_POS_CURRENT      605754
# AMT_INST_MIN_REGULARITY       264384
# AMT_PAYMENT_CURRENT           620093
# AMT_PAYMENT_TOTAL_CURRENT          0
# AMT_RECEIVABLE_PRINCIPAL           0
# AMT_RECIVABLE                      0
# AMT_TOTAL_RECEIVABLE               0
# CNT_DRAWINGS_ATM_CURRENT      605754
# CNT_DRAWINGS_CURRENT               0
# CNT_DRAWINGS_OTHER_CURRENT    605754
# CNT_DRAWINGS_POS_CURRENT      605754
# CNT_INSTALMENT_MATURE_CUM     264384
# NAME_CONTRACT_STATUS               0
# SK_DPD                             0
# SK_DPD_DEF                         0
# SK_ID_CURR                         0
# dtype: int64

# %%
def check_missed_values(df):
    df_null_percentage = df.isnull().sum() / df.shape[0] * 100
    df_null_percentage = df_null_percentage.drop(df_null_percentage[df_null_percentage == 0].index).sort_values(ascending= False).reset_index()
    df_null_percentage.columns = ["Feature", "Percentage"]
    return df_null_percentage

null_df = check_missed_values(CCBL)

# %%
plt.figure(figsize=(16,5))
sns.barplot(x=  null_df["Percentage"] , y= null_df["Feature"] )
# Out:
# <Axes: xlabel='Percentage', ylabel='Feature'>

# %%
CCBL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3227965 entries, 0 to 3227964
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   MONTHS_BALANCE              int64
#  2   AMT_BALANCE                 float64
#  3   AMT_CREDIT_LIMIT_ACTUAL     int64
#  4   AMT_DRAWINGS_ATM_CURRENT    float64
#  5   AMT_DRAWINGS_CURRENT        float64
#  6   AMT_DRAWINGS_OTHER_CURRENT  float64
#  7   AMT_DRAWINGS_POS_CURRENT    float64
#  8   AMT_INST_MIN_REGULARITY     float64
#  9   AMT_PAYMENT_CURRENT         float64
#  10  AMT_PAYMENT_TOTAL_CURRENT   float64
#  11  AMT_RECEIVABLE_PRINCIPAL    float64
#  12  AMT_RECIVABLE               float64
#  13  AMT_TOTAL_RECEIVABLE        float64
#  14  CNT_DRAWINGS_ATM_CURRENT    float64
#  15  CNT_DRAWINGS_CURRENT        int64
#  16  CNT_DRAWINGS_OTHER_CURRENT  float64
#  17  CNT_DRAWINGS_POS_CURRENT    float64
#  18  CNT_INSTALMENT_MATURE_CUM   float64
#  19  NAME_CONTRACT_STATUS        object
#  20  SK_DPD                      int64
#  21  SK_DPD_DEF                  int64
#  22  SK_ID_CURR                  int64
# dtypes: float64(15), int64(7), object(1)
# memory usage: 566.4+ MB

# %%
CCBL.describe().T
# Out:
#                                   count         mean        std          min  \
# SK_ID_PREV                 3,227,965.00 1,903,894.10 536,741.49 1,000,018.00
# MONTHS_BALANCE             3,227,965.00       -34.72      26.64       -96.00
# AMT_BALANCE                3,227,965.00    59,073.32 106,613.65  -420,250.18
# AMT_CREDIT_LIMIT_ACTUAL    3,227,965.00   152,953.57 163,709.20         0.00
# AMT_DRAWINGS_ATM_CURRENT   2,622,211.00     6,024.27  28,421.16    -6,827.31
# AMT_DRAWINGS_CURRENT       3,227,965.00     7,494.08  33,967.43    -6,211.62
# AMT_DRAWINGS_OTHER_CURRENT 2,622,211.00       298.49   8,396.19         0.00
# AMT_DRAWINGS_POS_CURRENT   2,622,211.00     2,884.15  20,388.33         0.00
# AMT_INST_MIN_REGULARITY    2,963,581.00     3,599.68   5,611.74         0.00
# AMT_PAYMENT_CURRENT        2,607,872.00    10,238.61  35,864.33         0.00
# AMT_PAYMENT_TOTAL_CURRENT  3,227,965.00     7,633.47  31,954.03         0.00
# AMT_RECEIVABLE_PRINCIPAL   3,227,965.00    56,700.18 102,824.20  -423,305.82
# AMT_RECIVABLE              3,227,965.00    58,862.64 106,274.73  -420,250.18
# AMT_TOTAL_RECEIVABLE       3,227,965.00    58,872.59 106,281.28  -420,250.18
# CNT_DRAWINGS_ATM_CURRENT   2,622,211.00         0.32       1.11         0.00
# CNT_DRAWINGS_CURRENT       3,227,965.00         0.70       3.17         0.00
# CNT_DRAWINGS_OTHER_CURRENT 2,622,211.00         0.00       0.08         0.00
# CNT_DRAWINGS_POS_CURRENT   2,622,211.00         0.54       3.19         0.00
# CNT_INSTALMENT_MATURE_CUM  2,963,581.00        21.09      19.99         0.00
# SK_DPD                     3,227,965.00         9.49      98.05         0.00
# SK_DPD_DEF                 3,227,965.00         0.29      19.57         0.00
# SK_ID_CURR                 3,227,965.00   153,654.24  88,571.21         0.00
#
#                                     25%          50%          75%          max
# SK_ID_PREV                 1,431,613.00 1,896,076.00 2,369,259.00 2,843,493.00
# MONTHS_BALANCE                   -56.00       -28.00       -11.00        -1.00
# AMT_BALANCE                        0.00         0.00    90,405.54 1,354,829.26
# AMT_CREDIT_LIMIT_ACTUAL       45,000.00   112,500.00   180,000.00 1,350,000.00
# AMT_DRAWINGS_ATM_CURRENT           0.00         0.00         0.00 2,115,000.00
# AMT_DRAWINGS_CURRENT               0.00         0.00         0.00 2,115,000.00
# AMT_DRAWINGS_OTHER_CURRENT         0.00         0.00         0.00 1,529,847.00
# AMT_DRAWINGS_POS_CURRENT           0.00         0.00         0.00 2,060,030.16
# AMT_INST_MIN_REGULARITY            0.00         0.00     6,750.00   202,882.01
# AMT_PAYMENT_CURRENT              155.70     2,923.02     9,000.00 4,289,207.45
# AMT_PAYMENT_TOTAL_CURRENT          0.00         0.00     6,750.00 4,278,315.69
# AMT_RECEIVABLE_PRINCIPAL           0.00         0.00    86,642.15 1,354,829.26
# AMT_RECIVABLE                      0.00         0.00    90,208.40 1,354,829.26
# AMT_TOTAL_RECEIVABLE               0.00         0.00    90,226.35 1,354,829.26
# CNT_DRAWINGS_ATM_CURRENT           0.00         0.00         0.00        51.00
# CNT_DRAWINGS_CURRENT               0.00         0.00         0.00       165.00
# CNT_DRAWINGS_OTHER_CURRENT         0.00         0.00         0.00        12.00
# CNT_DRAWINGS_POS_CURRENT           0.00         0.00         0.00       165.00
# CNT_INSTALMENT_MATURE_CUM          5.00        16.00        33.00       120.00
# SK_DPD                             0.00         0.00         0.00     2,831.00
# SK_DPD_DEF                         0.00         0.00         0.00     2,800.00
# SK_ID_CURR                    76,905.00   153,207.00   230,048.00   307,509.00

# %%
def draw_distribution(x, title,c):
    fig, ax = plt.subplots(2,1,figsize=(20,10))

    sns.distplot(x,ax=ax[0],color=c)
    ax[0].set(xlabel=None)
    ax[0].set_title('Histogram + KDE')

    sns.boxplot(x, ax=ax[1],color=c)
    ax[1].set(xlabel=None)
    ax[1].set_title('Boxplot')

    fig.suptitle(title, fontsize=20)
    plt.tight_layout()
    plt.show()

# %%
CCBL["NAME_CONTRACT_STATUS"].value_counts(normalize= True) * 100
# Out:
# NAME_CONTRACT_STATUS
# Active          96.55
# Completed        3.10
# Signed           0.31
# Demand           0.03
# Sent proposal    0.01
# Refused          0.00
# Approved         0.00
# Name: proportion, dtype: float64

# %%
## get the most recent record of this dataset
CCBL_filter = CCBL.sort_values(by=['MONTHS_BALANCE']).groupby(["SK_ID_CURR", "SK_ID_PREV"]).last().reset_index()
CCBL_filter
# Out:
#        SK_ID_CURR  SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  \
# 0               0     1745718              -1    12,814.60
# 1               1     1723965              -1   218,401.29
# 2               3     2613228              -1   140,479.15
# 3               7     2765329              -1         0.00
# 4               9     1989688              -1         0.00
# ...           ...         ...             ...          ...
# 87447      307501     1682952              -3         0.00
# 87448      307504     1025205              -1         0.00
# 87449      307505     2764693              -4         0.00
# 87450      307508     1320688              -1         0.00
# 87451      307509     1147091              -1         0.00
#
#        AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 0                       180000                      0.00
# 1                       225000                      0.00
# 2                       135000                      0.00
# 3                            0                       NaN
# 4                            0                      0.00
# ...                        ...                       ...
# 87447                   247500                       NaN
# 87448                    45000                      0.00
# 87449                   135000                       NaN
# 87450                   900000                       NaN
# 87451                        0                      0.00
#
#        AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 0                 25,976.25                        0.00
# 1                      0.00                        0.00
# 2                  3,653.05                        0.00
# 3                      0.00                         NaN
# 4                      0.00                        0.00
# ...                     ...                         ...
# 87447                  0.00                         NaN
# 87448                  0.00                        0.00
# 87449                  0.00                         NaN
# 87450                  0.00                         NaN
# 87451                  0.00                        0.00
#
#        AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY  ...  AMT_RECIVABLE  \
# 0                     25,976.25                     0.00  ...      12,814.60
# 1                          0.00                11,274.17  ...     218,401.29
# 2                      3,653.05                 7,008.61  ...     138,771.09
# 3                           NaN                     0.00  ...           0.00
# 4                          0.00                     0.00  ...           0.00
# ...                         ...                      ...  ...            ...
# 87447                       NaN                     0.00  ...           0.00
# 87448                      0.00                     0.00  ...           0.00
# 87449                       NaN                     0.00  ...           0.00
# 87450                       NaN                     0.00  ...           0.00
# 87451                      0.00                     0.00  ...           0.00
#
#        AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 0                 12,814.60                      0.00                    10
# 1                218,401.29                      0.00                     0
# 2                138,771.09                      0.00                     3
# 3                      0.00                       NaN                     0
# 4                      0.00                      0.00                     0
# ...                     ...                       ...                   ...
# 87447                  0.00                       NaN                     0
# 87448                  0.00                      0.00                     0
# 87449                  0.00                       NaN                     0
# 87450                  0.00                       NaN                     0
# 87451                  0.00                      0.00                     0
#
#        CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 0                            0.00                     10.00
# 1                            0.00                      0.00
# 2                            0.00                      3.00
# 3                             NaN                       NaN
# 4                            0.00                      0.00
# ...                           ...                       ...
# 87447                         NaN                       NaN
# 87448                        0.00                      0.00
# 87449                         NaN                       NaN
# 87450                         NaN                       NaN
# 87451                        0.00                      0.00
#
#        CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                           1.00                Active       0           0
# 1                           8.00                Active       0           0
# 2                           9.00                Active       0           0
# 3                           0.00             Completed       0           0
# 4                           1.00             Completed       0           0
# ...                          ...                   ...     ...         ...
# 87447                       0.00                Active       0           0
# 87448                      40.00                Active       0           0
# 87449                       0.00                Active       0           0
# 87450                       0.00                Active       0           0
# 87451                       9.00                Active       0           0
#
# [87452 rows x 23 columns]

# %%
Train_df = pd.read_csv(r"C:\Users\swift\Downloads\input\inputs\application_train.csv")
Train_df
# Out:
#         Unnamed: 0  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0                0       0         Cash loans           F            N
# 1                1       0         Cash loans           F            N
# 2                2       0         Cash loans           M            N
# 3                3       0         Cash loans           M            N
# 4                4       0         Cash loans           M            Y
# ...            ...     ...                ...         ...          ...
# 246004      246004       0         Cash loans           M            N
# 246005      246005       0         Cash loans           F            N
# 246006      246006       0         Cash loans           F            N
# 246007      246007       1         Cash loans           F            N
# 246008      246008       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL   AMT_CREDIT  \
# 0                    N             0        270,000.00 1,293,502.50
# 1                    Y             0        135,000.00   312,682.50
# 2                    Y             0        121,500.00   513,000.00
# 3                    Y             0         99,000.00   490,495.50
# 4                    Y             0        360,000.00 1,530,000.00
# ...                ...           ...               ...          ...
# 246004               N             0        157,500.00   254,700.00
# 246005               Y             0         72,000.00   269,550.00
# 246006               Y             0        153,000.00   677,664.00
# 246007               Y             0        171,000.00   370,107.00
# 246008               N             0        157,500.00   675,000.00
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21  \
# 0         35,698.50  ...                 0                0                0
# 1         29,686.50  ...                 0                0                0
# 2         21,865.50  ...                 0                0                0
# 3         27,517.50  ...                 0                0                0
# 4         42,075.00  ...                 0                0                0
# ...             ...  ...               ...              ...              ...
# 246004    27,558.00  ...                 0                0                0
# 246005    12,001.50  ...                 0                0                0
# 246006    29,979.00  ...                 0                0                0
# 246007    20,205.00  ...                 0                0                0
# 246008    49,117.50  ...                 0                0                0
#
#        AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 0                            0.00                      0.00
# 1                             NaN                       NaN
# 2                            0.00                      0.00
# 3                            0.00                      0.00
# 4                            0.00                      0.00
# ...                           ...                       ...
# 246004                        NaN                       NaN
# 246005                        NaN                       NaN
# 246006                       1.00                      0.00
# 246007                       0.00                      0.00
# 246008                       0.00                      0.00
#
#        AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 0                            0.00                       0.00
# 1                             NaN                        NaN
# 2                            0.00                       0.00
# 3                            0.00                       0.00
# 4                            0.00                       0.00
# ...                           ...                        ...
# 246004                        NaN                        NaN
# 246005                        NaN                        NaN
# 246006                       0.00                       1.00
# 246007                       0.00                       0.00
# 246008                       0.00                       2.00
#
#         AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  SK_ID_CURR
# 0                            0.00                        0.00      278621
# 1                             NaN                         NaN      139008
# 2                            0.00                        0.00      138348
# 3                            1.00                        1.00       64140
# 4                            0.00                        0.00      219374
# ...                           ...                         ...         ...
# 246004                        NaN                         NaN       90253
# 246005                        NaN                         NaN        9027
# 246006                       0.00                        1.00      163598
# 246007                       0.00                        0.00      300375
# 246008                       0.00                        1.00      258328
#
# [246009 rows x 123 columns]

# %% [markdown]
# # Feature

# %% [markdown]
# Number of Loan per customer

# %%
CCBL_filter["Completed_Flag"] = CCBL_filter["NAME_CONTRACT_STATUS"].apply(lambda x: 1 if x== "Completed" else 0)
CCBL_filter["Completed_Count"] = CCBL_filter.groupby(["SK_ID_CURR"])["Completed_Flag"].transform("sum")
CCBL_filter.drop(["Completed_Flag"], axis=1, inplace= True)
CCBL_filter
# Out:
#        SK_ID_CURR  SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  \
# 0               0     1745718              -1    12,814.60
# 1               1     1723965              -1   218,401.29
# 2               3     2613228              -1   140,479.15
# 3               7     2765329              -1         0.00
# 4               9     1989688              -1         0.00
# ...           ...         ...             ...          ...
# 87447      307501     1682952              -3         0.00
# 87448      307504     1025205              -1         0.00
# 87449      307505     2764693              -4         0.00
# 87450      307508     1320688              -1         0.00
# 87451      307509     1147091              -1         0.00
#
#        AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 0                       180000                      0.00
# 1                       225000                      0.00
# 2                       135000                      0.00
# 3                            0                       NaN
# 4                            0                      0.00
# ...                        ...                       ...
# 87447                   247500                       NaN
# 87448                    45000                      0.00
# 87449                   135000                       NaN
# 87450                   900000                       NaN
# 87451                        0                      0.00
#
#        AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 0                 25,976.25                        0.00
# 1                      0.00                        0.00
# 2                  3,653.05                        0.00
# 3                      0.00                         NaN
# 4                      0.00                        0.00
# ...                     ...                         ...
# 87447                  0.00                         NaN
# 87448                  0.00                        0.00
# 87449                  0.00                         NaN
# 87450                  0.00                         NaN
# 87451                  0.00                        0.00
#
#        AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY  ...  \
# 0                     25,976.25                     0.00  ...
# 1                          0.00                11,274.17  ...
# 2                      3,653.05                 7,008.61  ...
# 3                           NaN                     0.00  ...
# 4                          0.00                     0.00  ...
# ...                         ...                      ...  ...
# 87447                       NaN                     0.00  ...
# 87448                      0.00                     0.00  ...
# 87449                       NaN                     0.00  ...
# 87450                       NaN                     0.00  ...
# 87451                      0.00                     0.00  ...
#
#        AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 0                 12,814.60                      0.00                    10
# 1                218,401.29                      0.00                     0
# 2                138,771.09                      0.00                     3
# 3                      0.00                       NaN                     0
# 4                      0.00                      0.00                     0
# ...                     ...                       ...                   ...
# 87447                  0.00                       NaN                     0
# 87448                  0.00                      0.00                     0
# 87449                  0.00                       NaN                     0
# 87450                  0.00                       NaN                     0
# 87451                  0.00                      0.00                     0
#
#        CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 0                            0.00                     10.00
# 1                            0.00                      0.00
# 2                            0.00                      3.00
# 3                             NaN                       NaN
# 4                            0.00                      0.00
# ...                           ...                       ...
# 87447                         NaN                       NaN
# 87448                        0.00                      0.00
# 87449                         NaN                       NaN
# 87450                         NaN                       NaN
# 87451                        0.00                      0.00
#
#        CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                           1.00                Active       0           0
# 1                           8.00                Active       0           0
# 2                           9.00                Active       0           0
# 3                           0.00             Completed       0           0
# 4                           1.00             Completed       0           0
# ...                          ...                   ...     ...         ...
# 87447                       0.00                Active       0           0
# 87448                      40.00                Active       0           0
# 87449                       0.00                Active       0           0
# 87450                       0.00                Active       0           0
# 87451                       9.00                Active       0           0
#
#        Completed_Count
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    1
# ...                ...
# 87447                0
# 87448                0
# 87449                0
# 87450                0
# 87451                0
#
# [87452 rows x 24 columns]

# %%
CCBL_merged = pd.merge(Train_df[["SK_ID_CURR", "TARGET"]], CCBL_filter, how= "left", on=["SK_ID_CURR"])
CCBL_merged
# Out:
#         SK_ID_CURR  TARGET   SK_ID_PREV  MONTHS_BALANCE  AMT_BALANCE  \
# 0           278621       0          NaN             NaN          NaN
# 1           139008       0 1,489,396.00           -1.00         0.00
# 2           138348       0          NaN             NaN          NaN
# 3            64140       0          NaN             NaN          NaN
# 4           219374       0          NaN             NaN          NaN
# ...            ...     ...          ...             ...          ...
# 246465       90253       0          NaN             NaN          NaN
# 246466        9027       0          NaN             NaN          NaN
# 246467      163598       0          NaN             NaN          NaN
# 246468      300375       1          NaN             NaN          NaN
# 246469      258328       0          NaN             NaN          NaN
#
#         AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 0                           NaN                       NaN
# 1                    270,000.00                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 246465                      NaN                       NaN
# 246466                      NaN                       NaN
# 246467                      NaN                       NaN
# 246468                      NaN                       NaN
# 246469                      NaN                       NaN
#
#         AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 0                        NaN                         NaN
# 1                       0.00                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ...                      ...                         ...
# 246465                   NaN                         NaN
# 246466                   NaN                         NaN
# 246467                   NaN                         NaN
# 246468                   NaN                         NaN
# 246469                   NaN                         NaN
#
#         AMT_DRAWINGS_POS_CURRENT  ...  AMT_TOTAL_RECEIVABLE  \
# 0                            NaN  ...                   NaN
# 1                            NaN  ...                  0.00
# 2                            NaN  ...                   NaN
# 3                            NaN  ...                   NaN
# 4                            NaN  ...                   NaN
# ...                          ...  ...                   ...
# 246465                       NaN  ...                   NaN
# 246466                       NaN  ...                   NaN
# 246467                       NaN  ...                   NaN
# 246468                       NaN  ...                   NaN
# 246469                       NaN  ...                   NaN
#
#         CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 0                            NaN                   NaN
# 1                            NaN                  0.00
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# ...                          ...                   ...
# 246465                       NaN                   NaN
# 246466                       NaN                   NaN
# 246467                       NaN                   NaN
# 246468                       NaN                   NaN
# 246469                       NaN                   NaN
#
#         CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 246465                         NaN                       NaN
# 246466                         NaN                       NaN
# 246467                         NaN                       NaN
# 246468                         NaN                       NaN
# 246469                         NaN                       NaN
#
#         CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                             NaN                   NaN     NaN         NaN
# 1                            0.00                Active    0.00        0.00
# 2                             NaN                   NaN     NaN         NaN
# 3                             NaN                   NaN     NaN         NaN
# 4                             NaN                   NaN     NaN         NaN
# ...                           ...                   ...     ...         ...
# 246465                        NaN                   NaN     NaN         NaN
# 246466                        NaN                   NaN     NaN         NaN
# 246467                        NaN                   NaN     NaN         NaN
# 246468                        NaN                   NaN     NaN         NaN
# 246469                        NaN                   NaN     NaN         NaN
#
#         Completed_Count
# 0                   NaN
# 1                  0.00
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 246465              NaN
# 246466              NaN
# 246467              NaN
# 246468              NaN
# 246469              NaN
#
# [246470 rows x 25 columns]

# %%
fig, ax = plt.subplots(1,2, figsize= (12,6))
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_BALANCE'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_BALANCE'].dropna(), ax= ax[1]).set(title = "Defaulter")
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\325330494.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_BALANCE'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\325330494.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_BALANCE'].dropna(), ax= ax[1]).set(title = "Defaulter")
# [Text(0.5, 1.0, 'Defaulter')]

# %%
fig, ax = plt.subplots(1,2, figsize= (12,6))
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_CREDIT_LIMIT_ACTUAL'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_CREDIT_LIMIT_ACTUAL'].dropna(), ax= ax[1]).set(title = "Defaulter")
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\3219810853.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_CREDIT_LIMIT_ACTUAL'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\3219810853.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_CREDIT_LIMIT_ACTUAL'].dropna(), ax= ax[1]).set(title = "Defaulter")
# [Text(0.5, 1.0, 'Defaulter')]

# %%
fig, ax = plt.subplots(1,2, figsize= (12,6))
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_RECEIVABLE_PRINCIPAL'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_RECEIVABLE_PRINCIPAL'].dropna(), ax= ax[1]).set(title = "Defaulter")
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\123929311.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_RECEIVABLE_PRINCIPAL'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\123929311.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_RECEIVABLE_PRINCIPAL'].dropna(), ax= ax[1]).set(title = "Defaulter")
# [Text(0.5, 1.0, 'Defaulter')]

# %%
fig, ax = plt.subplots(1,2, figsize= (12,6))
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_RECIVABLE'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_RECIVABLE'].dropna(), ax= ax[1]).set(title = "Defaulter")
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\1368158570.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_RECIVABLE'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\1368158570.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_RECIVABLE'].dropna(), ax= ax[1]).set(title = "Defaulter")
# [Text(0.5, 1.0, 'Defaulter')]

# %%
fig, ax = plt.subplots(1,2, figsize= (12,6))
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_TOTAL_RECEIVABLE'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_TOTAL_RECEIVABLE'].dropna(), ax= ax[1]).set(title = "Defaulter")
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\2733345202.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 0]['AMT_TOTAL_RECEIVABLE'].dropna(), ax= ax[0]).set(title = "Non-defaulter")
# C:\Users\swift\AppData\Local\Temp\ipykernel_5496\2733345202.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(CCBL_merged[CCBL_merged["TARGET"] == 1]['AMT_TOTAL_RECEIVABLE'].dropna(), ax= ax[1]).set(title = "Defaulter")
# [Text(0.5, 1.0, 'Defaulter')]

# %%
sns.countplot(data=CCBL_merged,x=CCBL_merged['NAME_CONTRACT_STATUS'], hue='TARGET' )
# Out:
# <Axes: xlabel='NAME_CONTRACT_STATUS', ylabel='count'>

# %%
def plot_normalized_stacked_bar_chart(data, category_col, binary_col):
    '''
    input: 
        data: dataframe
        category_col: categorycal column
        binary_Col: target column
    '''
    grouped = data.groupby(category_col)[binary_col].value_counts(normalize=True).unstack()
    grouped.plot(kind='bar', stacked=True)
    plt.title('Normalized Stacked Bar Chart')
    plt.xlabel(category_col)
    plt.ylabel('Percentage')
    plt.show()

# %%
plot_normalized_stacked_bar_chart(CCBL_merged,"NAME_CONTRACT_STATUS", "TARGET")

# %% [markdown]
# ###NAME_CONTRACT_STATUS "Completed" and "Active" has less chance of defaulting. Borrowers with active contracts are currently engaged in the loan repayment process. For contracts marked as "completed," the borrower has already successfully fulfilled their loan obligations and repaid the debt in full.

# %%
import scorecardpy as sc

bins = sc.woebin(CCBL_merged[["TARGET", "AMT_BALANCE", "AMT_RECEIVABLE_PRINCIPAL", "AMT_TOTAL_RECEIVABLE"]], y="TARGET")
sc.woebin_plot(bins)
# Out:
# [INFO] creating woe binning ...
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:141: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).groupby(['variable', 'rowid', 'bin_chr'], group_keys=False).agg({'bad':sum,'good':sum})\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:141: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).groupby(['variable', 'rowid', 'bin_chr'], group_keys=False).agg({'bad':sum,'good':sum})\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:320: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   init_bin = dtm.groupby('bin', group_keys=False)['y'].agg([n0, n1])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:442: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binning_1bst_brk = binning_1bst_brk.groupby(['variable', 'bstbin'], group_keys=False)\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:442: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binning_1bst_brk = binning_1bst_brk.groupby(['variable', 'bstbin'], group_keys=False)\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:141: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).groupby(['variable', 'rowid', 'bin_chr'], group_keys=False).agg({'bad':sum,'good':sum})\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:141: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).groupby(['variable', 'rowid', 'bin_chr'], group_keys=False).agg({'bad':sum,'good':sum})\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:320: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   init_bin = dtm.groupby('bin', group_keys=False)['y'].agg([n0, n1])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:442: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binning_1bst_brk = binning_1bst_brk.groupby(['variable', 'bstbin'], group_keys=False)\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:442: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binning_1bst_brk = binning_1bst_brk.groupby(['variable', 'bstbin'], group_keys=False)\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:141: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).groupby(['variable', 'rowid', 'bin_chr'], group_keys=False).agg({'bad':sum,'good':sum})\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:141: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).groupby(['variable', 'rowid', 'bin_chr'], group_keys=False).agg({'bad':sum,'good':sum})\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:320: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   init_bin = dtm.groupby('bin', group_keys=False)['y'].agg([n0, n1])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:442: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binning_1bst_brk = binning_1bst_brk.groupby(['variable', 'bstbin'], group_keys=False)\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:414: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index()\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:442: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binning_1bst_brk = binning_1bst_brk.groupby(['variable', 'bstbin'], group_keys=False)\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# C:\Users\swift\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scorecardpy\woebin.py:443: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'good':sum, 'bad':sum}).reset_index().assign(bin=lambda x: x['bstbin'])\
# {'AMT_BALANCE': <Figure size 640x480 with 2 Axes>,
#  'AMT_RECEIVABLE_PRINCIPAL': <Figure size 640x480 with 2 Axes>,
#  'AMT_TOTAL_RECEIVABLE': <Figure size 640x480 with 2 Axes>}

# %% [markdown]
# AMT_RECEIVABLE_PRINCIPAL, AMT_TOTAL_RECEIVABLE
# The higher AMT_RECEIVABLE_PRINCIPAL, AMT_TOTAL_RECEIVABLE are, the more likely to pay their current loan on time. 6.4% of AMT_RECEIVABLE_PRINCIPAL, AMT_TOTAL_RECEIVABLE less than 30000 are tagged 1, compared to 13.8% of the customers with Amount receivable for principal greater than 30000.

# %% [markdown]
# AMT_PAYMENT_TOTAL_CURRENT
# The higher AMT_PAYMENT_TOTAL_CURRENT are, the more likely to pay their current loan on time. 6.9% of AMT_PAYMENT_TOTAL_CURRENT less than 500 are tagged 1, compared to 12.5% of the customers with pay during the month in total on the previous credit greater than 500.
